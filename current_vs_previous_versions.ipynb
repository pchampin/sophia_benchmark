# %% [markdown]
# # State of the current implementation
#
# This benchmark compares the performances of the latest version of [sophia](https://github.com/pchampin/sophia_rs) with previous versions.
#
# It was executed on an Intel® Core™ i7-10510U CPU @ 1.80GHz with 8 cores and 16 GiB of RAM.

# %%
# %matplotlib inline
from plot_utils import *

# %% [markdown]
# ## Evolution of Sophia
#
# The following graphs compare different versions of Sophia:
#
# * v0.1.0 compiles with rustc v1.35
# * v0.2.0 compiled with rustc v1.35
# * v0.3.0 compiled with rustc v1.41
# * v0.4.0 compiled with rustc v1.41
# * v0.5.2 compiled with rustc v1.43
#
# ### Evolution of the `query` test

# %%
VERSIONS = {
    "sophia-v0.1.0": "#AAAAAA",
    "sophia-v0.2.0": "#888888",
    "sophia-v0.3.0": "#996666",
    "sophia-v0.4.0": "#BB3333",
    "sophia-v0.5.2": "#EE0000",
    "sophia": "#00AA00",
}

plot_query_stats(load_data("query", *VERSIONS), color_key=VERSIONS)

# %% [markdown]
# ### Evolution of the `parse` test

# %%
data = load_data("parse", *VERSIONS)
my_plot(data, "t_parse", loglog=True, title="Time (in s) to parse an NT file", color_key=VERSIONS)

# %%
my_plot(data, "r_parse", title="Parse rate (in triple/s) from an NT file in memory", logx=True, color_key=VERSIONS)
